# %% [markdown]
# <a href="https://colab.research.google.com/github/tykimdream/Machine-Learning/blob/main/First_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hello World를 출력하시오

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Hello Machine Learning을 출력하시오

# %%
print("Hello Machine Learning")
# Out:
# Hello Machine Learning
